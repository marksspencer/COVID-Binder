# %% [markdown]
# # COVID-19 Data Visualization
# ## An experiment with JupyterLab for Python data-visualization

# %% [markdown]
# Start by loading the required Python libraries

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1103">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Next, define the pandas dataframe, sourced from "https://www150.statcan.gc.ca/"
# Note - I need to source the corect URL. Apparently it changes, likely daily.
# In a next iteration, I will have the code read from the URL/File & strip the extraneous text from the file before loading it.

# %%
df = pd.read_csv("COVID-Data.csv")

# %% [markdown]
# We need to sub-divide the data, as it is not particularly usable in this format. pandas will help with that !
# * df(1) would be the stripped down table of data
# * df(2) would hold the lookup table for reference

# %% [markdown]
# Now that we have a usable dataframe, lets set the X & Y variables

# %%
x = df['Case identifier number4']
y = df['Hospitalization 10']

# %% [markdown]
# Now, lets define the plot

# %%
p = figure()
p.line(x,y,line_width = 2)
# Out:
# GlyphRenderer(id='1138', ...)

# %% [markdown]
# Now lets draw the plot

# %%
show(p)
# Out:
#   <div class="bk-root" id="48fc9c81-01ce-40ea-ba84-eaa9dc95e201" data-root-id="1104"></div>

# %% [markdown]
# ## Outcomes
# So this little notebook didn't achieve its aim, only because it is a "snapshot in time" data-source. <BR>
#     If I had better understood the data-source requrements up-front I might have tried something a little "easier".
